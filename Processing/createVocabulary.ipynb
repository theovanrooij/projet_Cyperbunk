# %%
from preprocessing import Preprocess_list_of_English_Sentence
import pandas as pd

from collections import Counter

import wordcloud
import matplotlib.pyplot as plt

# %%
df = pd.read_json("../Scraping/wattpad/cyberpunk-merge.json",orient="record")

# %%
stories = " ".join(df["story_text"])

# %%
process_stories = Preprocess_list_of_English_Sentence(df["story_text"])

# %%
counterbis = Counter(" ".join(df["story_text"]).split(" "))

# %%
counter = Counter(" ".join(process_stories).split(" "))

# %%
counter.most_common(100)
# Out:
# [('one', 18535),
#  ('like', 16844),
#  ('said', 15299),
#  ('back', 14983),
#  ('would', 13053),
#  ('could', 12777),
#  ('time', 12339),
#  ('eye', 11805),
#  ('know', 10758),
#  ('get', 10506),
#  ('hand', 10074),
#  ('around', 9232),
#  ('dont', 8518),
#  ('see', 8316),
#  ('even', 8177),
#  ('head', 8084),
#  ('way', 7826),
#  ('didnt', 7703),
#  ('look', 7371),
#  ('still', 7180),
#  ('face', 7174),
#  ('right', 7106),
#  ('’', 6860),
#  ('u', 6752),
#  ('room', 6749),
#  ('door', 6736),
#  ('man', 6725),
#  ('going', 6664),
#  ('well', 6620),
#  ('something', 6590),
#  ('go', 6560),
#  ('away', 6471),
#  ('people', 6422),
#  ('two', 6328),
#  ('say', 6059),
#  ('de', 6018),
#  ('thing', 5989),
#  ('made', 5613),
#  ('thought', 5540),
#  ('make', 5478),
#  ('got', 5404),
#  ('want', 5353),
#  ('take', 5296),
#  ('first', 5190),
#  ('let', 5134),
#  ('think', 5126),
#  ('need', 5093),
#  ('much', 5075),
#  ('arm', 5067),
#  ('day', 5057),
#  ('light', 5044),
#  ('took', 5016),
#  ('left', 4789),
#  ('never', 4773),
#  ('come', 4739),
#  ('“', 4719),
#  ('place', 4693),
#  ('turned', 4670),
#  ('”', 4651),
#  ('good', 4646),
#  ('long', 4621),
#  ('voice', 4576),
#  ('behind', 4558),
#  ('side', 4525),
#  ('life', 4441),
#  ('body', 4396),
#  ('wasnt', 4318),
#  ('little', 4236),
#  ('another', 4210),
#  ('city', 4157),
#  ('new', 4118),
#  ('world', 4010),
#  ('felt', 3973),
#  ('really', 3845),
#  ('came', 3842),
#  ('knew', 3822),
#  ('find', 3815),
#  ('la', 3812),
#  ('small', 3733),
#  ('looking', 3665),
#  ('thats', 3645),
#  ('next', 3644),
#  ('wall', 3630),
#  ('every', 3598),
#  ('went', 3597),
#  ('though', 3548),
#  ('sure', 3547),
#  ('nothing', 3537),
#  ('year', 3497),
#  ('black', 3496),
#  ('last', 3468),
#  ('moment', 3454),
#  ('enough', 3430),
#  ('inside', 3429),
#  ('saw', 3393),
#  ('work', 3390),
#  ('red', 3379),
#  ('found', 3313),
#  ('tell', 3305),
#  ('girl', 3283)]

# %%
df_space = pd.read_json("../Scraping/wattpad/space-merge.json",orient="record")
process_stories_space = Preprocess_list_of_English_Sentence(df_space["story_text"])
counter_space = Counter(" ".join(process_stories_space).split(" "))
counter_space.most_common(100)

# %%
process_stories_space = Preprocess_list_of_English_Sentence(df_space["story_text"])
counter_space = Counter(" ".join(process_stories_space).split(" "))
counter_space.most_common(100)

# %%
counter_space = Counter(" ".join(process_stories_space).split(" "))
counter_space.most_common(100)

# %%
counter_space.most_common(1000)
# Out:
# [('said', 84068),
#  ('back', 61044),
#  ('one', 57630),
#  ('like', 57015),
#  ('time', 50546),
#  ('know', 46788),
#  ('eye', 44281),
#  ('would', 44064),
#  ('get', 42005),
#  ('dont', 41945),
#  ('could', 40833),
#  ('hand', 38972),
#  ('go', 37594),
#  ('didnt', 37249),
#  ('say', 33867),
#  ('around', 33864),
#  ('see', 33787),
#  ('look', 33661),
#  ('head', 30846),
#  ('u', 28172),
#  ('well', 28082),
#  ('going', 28019),
#  ('still', 27971),
#  ('face', 27836),
#  ('two', 27758),
#  ('even', 27317),
#  ('way', 26805),
#  ('want', 26702),
#  ('people', 26674),
#  ('let', 25538),
#  ('thing', 25501),
#  ('room', 25500),
#  ('right', 23900),
#  ('little', 23686),
#  ('got', 23648),
#  ('away', 23563),
#  ('something', 23545),
#  ('come', 23047),
#  ('think', 22830),
#  ('take', 22311),
#  ('good', 21899),
#  ('thought', 21894),
#  ('door', 21157),
#  ('make', 21141),
#  ('really', 20569),
#  ('ship', 20317),
#  ('day', 20032),
#  ('made', 19912),
#  ('much', 19525),
#  ('need', 19184),
#  ('took', 18983),
#  ('first', 18954),
#  ('saw', 18490),
#  ('lin', 18077),
#  ('looking', 18038),
#  ('man', 17856),
#  ('also', 17314),
#  ('long', 17113),
#  ('felt', 17101),
#  ('turned', 16976),
#  ('came', 16958),
#  ('never', 16556),
#  ('arm', 16541),
#  ('went', 16324),
#  ('“', 16138),
#  ('”', 15976),
#  ('cant', 15848),
#  ('help', 15713),
#  ('voice', 15565),
#  ('left', 15236),
#  ('thats', 15172),
#  ('tell', 14859),
#  ('human', 14852),
#  ('behind', 14744),
#  ('yn', 14710),
#  ('knew', 14638),
#  ('everyone', 14563),
#  ('side', 14422),
#  ('find', 14373),
#  ('smile', 14325),
#  ('’', 14204),
#  ('feel', 13957),
#  ('life', 13939),
#  ('next', 13935),
#  ('small', 13816),
#  ('put', 13703),
#  ('sure', 13378),
#  ('oh', 13211),
#  ('wasnt', 13127),
#  ('towards', 13017),
#  ('girl', 12992),
#  ('body', 12976),
#  ('year', 12761),
#  ('space', 12718),
#  ('another', 12659),
#  ('ill', 12651),
#  ('anything', 12576),
#  ('doctor', 12563),
#  ('word', 12392),
#  ('told', 12121)]

# %%
wc = wordcloud.WordCloud(
    background_color = 'white', 
    max_words=200,
    max_font_size=100
)

wc.generate_from_frequencies(counter)
plt.imshow(wc)
plt.axis('off')
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
wc = wordcloud.WordCloud(
    background_color = 'white', 
    max_words=200,
    max_font_size=100
)

wc.generate_from_frequencies(counter_space)
plt.imshow(wc)
plt.axis('off')
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
df_romance = pd.read_json("../Scraping/wattpad/romance-merge.json",orient="record")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-71a82e3def5b> in <module>
#       1 df_romance = pd.read_json("../Scraping/wattpad/romance-merge.json",orient="record")
# ----> 2 process_stories_romance = Preprocess_list_of_English_Sentence(df_romance["story_text"])
#
# d:\Documents\Cours\ESIEE\E4\Semestre 2\projet_Cyperbunk\Processing\preprocessing.py in Preprocess_list_of_English_Sentence(listofSentence)
#      41         words_lemmatize = (Englishlemmatizer.lemmatize(w) for w in words_w_stopwords)
#      42
# ---> 43         sentence_clean = ' '.join(w for w in words_lemmatize if w.lower() in Ewords or not w.isalpha())
#      44         # rebuild the text
#      45         preprocess_list.append(sentence_clean)
#
# d:\Documents\Cours\ESIEE\E4\Semestre 2\projet_Cyperbunk\Processing\preprocessing.py in <genexpr>(.0)
#      41         words_lemmatize = (Englishlemmatizer.lemmatize(w) for w in words_w_stopwords)
#      42
# ---> 43         sentence_clean = ' '.join(w for w in words_lemmatize if w.lower() in Ewords or not w.isalpha())
#      44         # rebuild the text
#      45         preprocess_list.append(sentence_clean)
#
# d:\Documents\Cours\ESIEE\E4\Semestre 2\projet_Cyperbunk\Processing\preprocessing.py in <genexpr>(.0)
#      39         words_w_stopwords = [i for i in tokenize_sentence if i not in stopwords]
#      40
# ---> 41         words_lemmatize = (Englishlemmatizer.lemmatize(w) for w in words_w_stopwords)
#      42
#      43         sentence_clean = ' '.join(w for w in words_lemmatize if w.lower() in Ewords or not w.isalpha())
#
# D:\Logiciel\Anaconda\lib\site-packages\nltk\stem\wordnet.py in lemmatize(self, word, pos)
#      36
#      37     def lemmatize(self, word, pos=NOUN):
# ---> 38         lemmas = wordnet._morphy(word, pos)
#      39         return min(lemmas, key=len) if lemmas else word
#      40
#
# D:\Logiciel\Anaconda\lib\site-packages\nltk\corpus\reader\wordnet.py in _morphy(self, form, pos, check_exceptions)
#    1882             ]
#    1883
# -> 1884         def filter_forms(forms):
#    1885             result = []
#    1886             seen = set()
#
# KeyboardInterrupt:

# %%
p2 = df_romance["story_text"][int(len(df_romance["story_text"])/2):]

# %%
process_stories_romance = Preprocess_list_of_English_Sentence(p1)

# %%
process2 = Preprocess_list_of_English_Sentence(p2)

# %%
len(process_stories_romance + process2)
# Out:
# 1198

# %%
len(counter_romance)
# Out:
# 59280

# %%
counter_romance = Counter(" ".join(process_stories_romance + process2).split(" "))
counter_romance.less_common(100)
# Out:
# [('said', 163217),
#  ('like', 128248),
#  ('eye', 119643),
#  ('back', 118944),
#  ('know', 108745),
#  ('dont', 102200),
#  ('one', 94566),
#  ('hand', 89467),
#  ('time', 87577),
#  ('get', 87090),
#  ('would', 86002),
#  ('didnt', 81503),
#  ('look', 80560),
#  ('say', 79249),
#  ('go', 75281),
#  ('want', 74023),
#  ('could', 73148),
#  ('face', 70922),
#  ('head', 68832),
#  ('see', 68692),
#  ('even', 66210),
#  ('going', 65597),
#  ('around', 64572),
#  ('room', 60744),
#  ('let', 53863),
#  ('still', 53112),
#  ('u', 52866),
#  ('door', 52768),
#  ('away', 52050),
#  ('way', 51080),
#  ('right', 48663),
#  ('think', 48314),
#  ('got', 47955),
#  ('make', 46733),
#  ('something', 46421),
#  ('come', 46254),
#  ('take', 45211),
#  ('day', 45135),
#  ('really', 44968),
#  ('thought', 44686),
#  ('well', 44636),
#  ('love', 44505),
#  ('smile', 43188),
#  ('thing', 42333),
#  ('much', 42196),
#  ('never', 41500),
#  ('feel', 40955),
#  ('made', 40274),
#  ('little', 39766),
#  ('good', 39761),
#  ('tell', 39731),
#  ('looking', 39123),
#  ('felt', 38164),
#  ('arm', 37341),
#  ('need', 36842),
#  ('cant', 36403),
#  ('took', 35857),
#  ('first', 35583),
#  ('went', 35467),
#  ('two', 34972),
#  ('voice', 34464),
#  ('girl', 34117),
#  ('came', 32096),
#  ('saw', 31751),
#  ('guy', 31593),
#  ('towards', 31159),
#  ('bed', 30995),
#  ('wasnt', 30510),
#  ('turned', 30329),
#  ('people', 30290),
#  ('left', 30257),
#  ('told', 30051),
#  ('knew', 29980),
#  ('sure', 29719),
#  ('ill', 29548),
#  ('man', 29537),
#  ('thats', 29158),
#  ('anything', 29083),
#  ('hair', 28768),
#  ('life', 28549),
#  ('next', 28380),
#  ('lip', 27641),
#  ('oh', 27208),
#  ('since', 27191),
#  ('word', 27007),
#  ('friend', 26983),
#  ('long', 26937),
#  ('last', 26548),
#  ('body', 26402),
#  ('someone', 26349),
#  ('front', 26302),
#  ('help', 26077),
#  ('put', 25872),
#  ('already', 25824),
#  ('side', 25809),
#  ('always', 25787),
#  ('making', 25385),
#  ('car', 25354),
#  ('also', 25326),
#  ('everything', 25243)]

# %%
counter_romance.most_common(100)
# Out:
# [('said', 163217),
#  ('like', 128248),
#  ('eye', 119643),
#  ('back', 118944),
#  ('know', 108745),
#  ('dont', 102200),
#  ('one', 94566),
#  ('hand', 89467),
#  ('time', 87577),
#  ('get', 87090),
#  ('would', 86002),
#  ('didnt', 81503),
#  ('look', 80560),
#  ('say', 79249),
#  ('go', 75281),
#  ('want', 74023),
#  ('could', 73148),
#  ('face', 70922),
#  ('head', 68832),
#  ('see', 68692),
#  ('even', 66210),
#  ('going', 65597),
#  ('around', 64572),
#  ('room', 60744),
#  ('let', 53863),
#  ('still', 53112),
#  ('u', 52866),
#  ('door', 52768),
#  ('away', 52050),
#  ('way', 51080),
#  ('right', 48663),
#  ('think', 48314),
#  ('got', 47955),
#  ('make', 46733),
#  ('something', 46421),
#  ('come', 46254),
#  ('take', 45211),
#  ('day', 45135),
#  ('really', 44968),
#  ('thought', 44686),
#  ('well', 44636),
#  ('love', 44505),
#  ('smile', 43188),
#  ('thing', 42333),
#  ('much', 42196),
#  ('never', 41500),
#  ('feel', 40955),
#  ('made', 40274),
#  ('little', 39766),
#  ('good', 39761),
#  ('tell', 39731),
#  ('looking', 39123),
#  ('felt', 38164),
#  ('arm', 37341),
#  ('need', 36842),
#  ('cant', 36403),
#  ('took', 35857),
#  ('first', 35583),
#  ('went', 35467),
#  ('two', 34972),
#  ('voice', 34464),
#  ('girl', 34117),
#  ('came', 32096),
#  ('saw', 31751),
#  ('guy', 31593),
#  ('towards', 31159),
#  ('bed', 30995),
#  ('wasnt', 30510),
#  ('turned', 30329),
#  ('people', 30290),
#  ('left', 30257),
#  ('told', 30051),
#  ('knew', 29980),
#  ('sure', 29719),
#  ('ill', 29548),
#  ('man', 29537),
#  ('thats', 29158),
#  ('anything', 29083),
#  ('hair', 28768),
#  ('life', 28549),
#  ('next', 28380),
#  ('lip', 27641),
#  ('oh', 27208),
#  ('since', 27191),
#  ('word', 27007),
#  ('friend', 26983),
#  ('long', 26937),
#  ('last', 26548),
#  ('body', 26402),
#  ('someone', 26349),
#  ('front', 26302),
#  ('help', 26077),
#  ('put', 25872),
#  ('already', 25824),
#  ('side', 25809),
#  ('always', 25787),
#  ('making', 25385),
#  ('car', 25354),
#  ('also', 25326),
#  ('everything', 25243)]

# %%
wc = wordcloud.WordCloud(
    background_color = 'white', 
    max_words=200,
    max_font_size=100
)

wc.generate_from_frequencies(counter_romance)
plt.imshow(wc)
plt.axis('off')
# Out:
# (-0.5, 399.5, 199.5, -0.5)
