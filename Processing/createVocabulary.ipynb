# %%
import pandas as pd

from collections import Counter

import wordcloud
import matplotlib.pyplot as plt
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\theov\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\theov\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\theov\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\theov\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
df = pd.read_json("../Scraping/wattpad/romance-merge.json",orient="record")

# %%
df["preprocess_story_text"] = df["story_text"].apply(Preprocess_English_Sentence)

# %%
stories = " ".join(df["preprocess_story_text"]).split(" ")

# %%
counter = Counter(" ".join(stories).split(" "))

# %%
vocab = [word[0] for word in counter.most_common(3000)]

# %%
f=open('vocab.txt','w',encoding="utf-8")
s1='\n'.join(vocab)
f.write(s1)
f.close()

# %%
json_dump = df.to_json(path_or_buf='processed_files/wattpad/romance-merge.json',orient = 'records',indent=1)

# %%
df_space = pd.read_json("../Scraping/wattpad/space-merge.json",orient="record")
process_stories_space = Preprocess_list_of_English_Sentence(df_space["story_text"])
counter_space = Counter(" ".join(process_stories_space).split(" "))
counter_space.most_common(100)

# %%
process_stories_space = Preprocess_list_of_English_Sentence(df_space["story_text"])
counter_space = Counter(" ".join(process_stories_space).split(" "))
counter_space.most_common(100)

# %%
counter_space = Counter(" ".join(process_stories_space).split(" "))
counter_space.most_common(100)

# %%
counter_space.most_common(1000)

# %%
import os
os.listdir("../Processing/processed_files/wattpad")
# Out:
# ['.ipynb_checkpoints', 'cyberpunk-merge.json', 'romance-encoded.json']

# %%
df = pd.read_json("../Processing/processed_files/wattpad/cyberpunk-merge.json",orient="records")

# %%
df.head(2)
# Out:
#                                          story_title  \
# 0               (Hiccup X reader) The One You Needed
# 1   Falling In Love With Tsundere Villainess Afte...
#
#                                             story_id  reads votes  chapterNb  \
# 0       262498819-hiccup-x-reader-the-one-you-needed   136K  3.5K         25
# 1  297890055-falling-in-love-with-tsundere-villai...  29.2K  1.6K         60
#
#    first_update   last_update  \
# 0  Mar 17, 2021  Jun 12, 2021
# 1  ished Jan 11        Jan 12
#
#                                           story_text  \
# 0  YOUR POV Up in the air... High, above the dapp...
# 1  JLL Translations T/N: Hi guys! It’s my first t...
#
#                                preprocess_story_text     language  \
# 0  air high dappled cloud feel alive place feel a...  __label__en
# 1  translation hi guy ’ first time ever novel adv...  __label__en
#
#                                        encoded_story  \
# ...

# %%
stories = " ".join(df["preprocess_story_text"]).split(" ")

# %%
counter_cyberpunk = Counter(" ".join(df["preprocess_story_text"]).split(" "))

# %%
wc = wordcloud.WordCloud(
    background_color = 'white', 
    max_words=200,
    max_font_size=100
)

wc.generate_from_frequencies(counter_cyberpunk)
plt.imshow(wc)
plt.axis('off')
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
wc = wordcloud.WordCloud(
    background_color = 'white', 
    max_words=200,
    max_font_size=100
)

wc.generate_from_frequencies(counter_space)
plt.imshow(wc)
plt.axis('off')

# %%
df_romance = pd.read_json("../Scraping/wattpad/romance-merge.json",orient="record")

# %%
p2 = df_romance["story_text"][int(len(df_romance["story_text"])/2):]

# %%
process_stories_romance = Preprocess_list_of_English_Sentence(p1)

# %%
process2 = Preprocess_list_of_English_Sentence(p2)

# %%
len(process_stories_romance + process2)

# %%
len(counter_romance)

# %%
counter_romance = Counter(" ".join(process_stories_romance + process2).split(" "))
counter_romance.less_common(100)

# %%
counter_romance.most_common(100)

# %%
wc = wordcloud.WordCloud(
    background_color = 'white', 
    max_words=200,
    max_font_size=100
)

wc.generate_from_frequencies(counter_romance)
plt.imshow(wc)
plt.axis('off')
