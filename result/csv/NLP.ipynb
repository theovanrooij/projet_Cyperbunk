# %%
from sklearn.feature_extraction.text import CountVectorizer
import numpy as np
import pandas as pd
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# %%
cyberpunkforums=pd.read_json('result/json/cyberpunkforums.json')

# %%
cyberpunkforums.head()
# Out:
#    postId  postNb       postDate  \
# 0  p60291       1  1640736000000
# 1  p60298       2  1640995200000
# 2  p60300       3  1640995200000
# 3  p60370       4  1642636800000
# 4  p60378       5  1642723200000
#
#                                              content  \
# 0  [Scientists convinced a petri dish of brain ce...
# 1  [Things seem kind of slow here, which is cool ...
# 2  [At least the learning curve is quicker than t...
# 3  [Can't wait for my brain to be chopped up and ...
# 4                                  [Welcome welcome]
#
#                                           blockquote  \
# 0                                                 []
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4  [Can't wait for my brain to be chopped up and ...
#
#                                                  img  \
# 0                                                 []
# 1  [https://cyberpunkforums.com/img/smilies/lol.gif]
# 2                                                 []
# 3                                                 []
# 4                                                 []
#
#                                        links   categorie  \
# 0  [https://ftw.usatoday.com/2021/12/scient]  Subversion
# 1                                         []  Subversion
# 2                                         []  Subversion
# 3                                         []  Subversion
# 4                                         []  Subversion
#
#                                           topic  Year
# 0  Human brain cells in a dish are playing pong  2021
# 1  Human brain cells in a dish are playing pong  2022
# 2  Human brain cells in a dish are playing pong  2022
# 3  Human brain cells in a dish are playing pong  2022
# 4  Human brain cells in a dish are playing pong  2022

# %%
len(cyberpunkforums.Year.unique())
# Out:
# 12

# %%
cyberpunkforums.Year.unique()
# Out:
# array([2021, 2022, 2018, 2019, 2020, 2012, 2011, 2013, 2015, 2014, 2017,
#        2016], dtype=int64)

# %%
cyberpunkforums['content']=cyberpunkforums.apply(lambda x: str(x['content']).replace('[','').replace(']',''),axis=1)

# %%
cyberpunkforums.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53369 entries, 0 to 53368
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   postId      53369 non-null  object
#  1   postNb      53369 non-null  int64
#  2   postDate    53369 non-null  int64
#  3   content     53369 non-null  object
#  4   blockquote  53369 non-null  object
#  5   img         53369 non-null  object
#  6   links       53369 non-null  object
#  7   categorie   53369 non-null  object
#  8   topic       53369 non-null  object
#  9   Year        53369 non-null  int64
# dtypes: int64(3), object(7)
# memory usage: 4.1+ MB

# %%
cyberpunkforums.head(2)
# Out:
#    postId  postNb       postDate  \
# 0  p60291       1  1640736000000
# 1  p60298       2  1640995200000
#
#                                              content blockquote  \
# 0  "Scientists convinced a petri dish of brain ce...         []
# 1  "Things seem kind of slow here, which is cool ...         []
#
#                                                  img  \
# 0                                                 []
# 1  [https://cyberpunkforums.com/img/smilies/lol.gif]
#
#                                        links   categorie  \
# 0  [https://ftw.usatoday.com/2021/12/scient]  Subversion
# 1                                         []  Subversion
#
#                                           topic  Year
# 0  Human brain cells in a dish are playing pong  2021
# 1  Human brain cells in a dish are playing pong  2022

# %% [markdown]
# ###  处理分词等数据

# %%
import nltk
import string
# English Preprocessing Base
from nltk.stem import WordNetLemmatizer
# nltk.download('words')

# %%
# nltk.download([
#      "names",
#     "stopwords",
#     "state_union",
#     "twitter_samples",
#      "movie_reviews",
#     "averaged_perceptron_tagger",
#     "vader_lexicon",
#     "punkt",
# ])

# %%
# English Pre-processing
stopwords = nltk.corpus.stopwords.words('english')
Ewords = set(nltk.corpus.words.words())
Englishlemmatizer = WordNetLemmatizer()

# %%
# Define English Pre-processing Function
def Preprocess_list_of_English_Sentence(listofSentence):
    preprocess_list = []
    for sentence in listofSentence :
        
        sentence_w_punct = "".join([i.lower() for i in sentence if i not in string.punctuation])
        
        sentence_w_num = ''.join(i for i in sentence_w_punct if not i.isdigit())
        
        tokenize_sentence = nltk.tokenize.word_tokenize(sentence_w_num)
        
        words_w_stopwords = [i for i in tokenize_sentence if i not in stopwords]
        
        words_lemmatize = (Englishlemmatizer.lemmatize(w) for w in words_w_stopwords)
        
        sentence_clean = ' '.join(w for w in words_lemmatize if w.lower() in Ewords or not w.isalpha())
        # rebuild the text
        preprocess_list.append(sentence_clean)

    return preprocess_list

# %%
cyberpunkforums['content']=Preprocess_list_of_English_Sentence(cyberpunkforums['content'])

# %%
cyberpunkforums.head(2)
# Out:
#    postId  postNb       postDate  \
# 0  p60291       1  1640736000000
# 1  p60298       2  1640995200000
#
#                                              content blockquote  \
# 0  scientist convinced dish brain cell theyre pad...         []
# 1  thing seem kind slow cool kind slow however im...         []
#
#                                                  img  \
# 0                                                 []
# 1  [https://cyberpunkforums.com/img/smilies/lol.gif]
#
#                                        links   categorie  \
# 0  [https://ftw.usatoday.com/2021/12/scient]  Subversion
# 1                                         []  Subversion
#
#                                           topic  Year
# 0  Human brain cells in a dish are playing pong  2021
# 1  Human brain cells in a dish are playing pong  2022

# %%
#cyberpunkforums.to_csv('result/csv1/cyberpunkforums.csv')

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import matplotlib

text = cyberpunkforums['content'].values 
matplotlib.rcParams['figure.figsize']=(10.0,5.0)

wordcloud = WordCloud().generate(str(text))

plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %% [markdown]
# ## 词频统计

# %%
fd = nltk.FreqDist(cyberpunkforums['content'])
fd.most_common(10)
# Out:
# [('', 2895),
#  ('welcome', 47),
#  ('thanks', 44),
#  ('nice', 43),
#  ('thank', 30),
#  ('yes', 28),
#  ('yeah', 24),
#  ('like', 22),
#  ('love', 22),
#  ('cool', 22)]

# %% [markdown]
# ### 情感分析，方法一

# %%
from textblob import TextBlob
from snownlp import SnowNLP

# %%
from textblob import TextBlob
blob = TextBlob(cyberpunkforums['content'][2])
blob
# Out:
# TextBlob("least learning curve ai little boy")

# %%
blob.sentences
# Out:
# [Sentence("least learning curve ai little boy")]

# %%
blob.sentiment
# Out:
# Sentiment(polarity=-0.24375, subjectivity=0.45)

# %%
blob.sentiment[0]
# Out:
# -0.24375

# %%
text = cyberpunkforums['content'].iloc[2]

# %%
from snownlp import SnowNLP
s = SnowNLP(text)

# %%
s.sentiments
# Out:
# 0.1956519142229829

# %%
def get_sentiment_en(text):
    s = TextBlob(text).sentiment[0]
    return s

# %%
vrow = cyberpunkforums.shape[0]
cyberpunkforums["sentiment"] = cyberpunkforums.content.apply(get_sentiment_en)
cyberpunkforums["sentiment"].unique()

# %%
for i in range(vrow):
    text = cyberpunkforums['content'].iloc[i]
    cyberpunkforums["sentiment"][i]=get_sentiment_en(text)
# Out:
# C:\Users\alplh\AppData\Local\Temp/ipykernel_4332/2660103228.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cyberpunkforums["sentiment"][i]=get_sentiment_en(text)

# %%
#cyberpunkforums["sentiment"] = cyberpunkforums.content.apply(get_sentiment_en)

# %%
cyberpunkforums.head(4)
# Out:
#    postId  postNb       postDate  \
# 0  p60291       1  1640736000000
# 1  p60298       2  1640995200000
# 2  p60300       3  1640995200000
# 3  p60370       4  1642636800000
#
#                                              content blockquote  \
# 0  scientist convinced dish brain cell theyre pad...         []
# 1  thing seem kind slow cool kind slow however im...         []
# 2                 least learning curve ai little boy         []
# 3      cant wait brain chopped turned organic latest         []
#
#                                                  img  \
# 0                                                 []
# 1  [https://cyberpunkforums.com/img/smilies/lol.gif]
# 2                                                 []
# 3                                                 []
#
#                                        links   categorie  \
# 0  [https://ftw.usatoday.com/2021/12/scient]  Subversion
# 1                                         []  Subversion
# 2                                         []  Subversion
# 3                                         []  Subversion
#
#                                           topic  Year  sentiment
# 0  Human brain cells in a dish are playing pong  2021  -0.091667
# 1  Human brain cells in a dish are playing pong  2022   0.144792
# 2  Human brain cells in a dish are playing pong  2022  -0.243750
# 3  Human brain cells in a dish are playing pong  2022   0.500000

# %%
np.argmin(cyberpunkforums["sentiment"])
# Out:
# 2357

# %%
cyberpunkforums["content"][2357]
# Out:
# 'worst sneaking'

# %%
sum_sent = cyberpunkforums.groupby(by=["Year"]).sum()["sentiment"]
mean_sent = cyberpunkforums.groupby(by=["Year"]).mean()["sentiment"]

# %%
years = np.arange(2011,2023,1)
print(years)
# Out:
# [2011 2012 2013 2014 2015 2016 2017 2018 2019 2020 2021 2022]

# %%
plt.bar(years,mean_sent)
# Out:
# <BarContainer object of 12 artists>

# %%
plt.plot(years,mean_sent,'bo-',label='type2')

# %%
plt.plot(years,sum_sent,'bo-',label='type2')

# %%
cyberpunkforums.to_csv('result/csv1/cyberpunkforums.csv')

# %% [markdown]
# ### 情感分析方法2

# %%
from nltk.sentiment import SentimentIntensityAnalyzer
sia = SentimentIntensityAnalyzer()
sia.polarity_scores(cyberpunkforums['content'].iloc[1])
# Out:
# {'neg': 0.117, 'neu': 0.608, 'pos': 0.275, 'compound': 0.9814}

# %%
def get_sentiment_en1(text):
    sia = SentimentIntensityAnalyzer()
    s1=sia.polarity_scores(text)
    return s1

# %%
cyberpunkforums["sentiment_nlyk"] = cyberpunkforums.content.apply(get_sentiment_en1)

# %%
cyberpunkforums.head(2)
# Out:
#    postId  postNb       postDate  \
# 0  p60291       1  1640736000000
# 1  p60298       2  1640995200000
#
#                                              content blockquote  \
# 0  scientist convinced dish brain cell theyre pad...         []
# 1  thing seem kind slow cool kind slow however im...         []
#
#                                                  img  \
# 0                                                 []
# 1  [https://cyberpunkforums.com/img/smilies/lol.gif]
#
#                                        links   categorie  \
# 0  [https://ftw.usatoday.com/2021/12/scient]  Subversion
# 1                                         []  Subversion
#
#                                           topic  Year  sentiment  \
# 0  Human brain cells in a dish are playing pong  2021  -0.091667
# 1  Human brain cells in a dish are playing pong  2022   0.144792
#
#                                       sentiment_nlyk
# 0  {'neg': 0.0, 'neu': 0.791, 'pos': 0.209, 'comp...
# 1  {'neg': 0.117, 'neu': 0.608, 'pos': 0.275, 'co...

# %% [markdown]
# ### Reddit

# %%
reddit4=pd.read_json('result/json/reddit4.json')

# %%
reddit4.head(2)
# Out:
#                                                title       date text  \
# 0  HK : wearable face projector to avoid face rec... 2020-03-01   []
# 1                                          Akira Gif 2018-03-02   []
#
#                                              Comment   vote  \
# 0  [Thats cool, but how blinded are you wearing t...  54500
# 1  [The first thing I thought was "hey look, actu...  10000
#
#                              image  Year
# 0                             None  2020
# 1  https://i.imgur.com/enfw4eu.gif  2018

# %%
reddit4["Comment"]=reddit4.apply(lambda x: str(x['Comment']).replace('[','').replace(']',''),axis=1)

# %%
reddit4["Comment"]=Preprocess_list_of_English_Sentence(reddit4["Comment"])

# %%
reddit4.head(2)
# Out:
#                                                title       date text  \
# 0  HK : wearable face projector to avoid face rec... 2020-03-01   []
# 1                                          Akira Gif 2018-03-02   []
#
#                                              Comment   vote  \
# 0  thats cool blinded wearing said eye pull yep a...  54500
# 1  first thing thought hey look actual top thats ...  10000
#
#                              image  Year
# 0                             None  2020
# 1  https://i.imgur.com/enfw4eu.gif  2018

# %%
text = reddit4["Comment"].values 
matplotlib.rcParams['figure.figsize']=(10.0,5.0)

wordcloud = WordCloud().generate(str(text))

plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
vrow = reddit4.shape[0]
reddit4["sentiment"] = reddit4.Comment.apply(get_sentiment_en)

# %%
for i in range(vrow):
    text = reddit4["Comment"] .iloc[i]
    reddit4["sentiment"][i]=get_sentiment_en(text)
# Out:
# C:\Users\alplh\AppData\Local\Temp/ipykernel_4332/3901957522.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reddit4["sentiment"][i]=get_sentiment_en(text)

# %%
reddit4.head(3)
# Out:
#                                                title       date text  \
# 0  HK : wearable face projector to avoid face rec... 2020-03-01   []
# 1                                          Akira Gif 2018-03-02   []
# 2  Tron rollercoaster Shanghai Disneyland giving ... 2018-03-02   []
#
#                                              Comment   vote  \
# 0  thats cool blinded wearing said eye pull yep a...  54500
# 1  first thing thought hey look actual top thats ...  10000
# 2  tron legacy rated film story might bit pull pu...   7700
#
#                                  image  Year  sentiment
# 0                                 None  2020   0.036216
# 1      https://i.imgur.com/enfw4eu.gif  2018   0.212592
# 2  https://i.redd.it/yxomyotbcvd11.jpg  2018   0.065008

# %%
np.argmin(reddit4["sentiment"])
# Out:
# 122

# %%
reddit4["Comment"][122]
# Out:
# 'real unedited local news thats concerning say least ’ right extremely dangerous democracy numerous local station regularly script yes one company control hundred local news station around country right wing bias onto station require station air documentary virus china week ago public scrutiny criticism back lobby heavily law limiting concentration medium ownership real threat democracy happening decade yes group large number local news network station occasionally air segment propaganda time lot news station ’ name get script medium group local news station u extremely conservative organization force station air must air piece like medium ago reply script local news show heavily right wing time time report conspiracy theory worst part people paying subscription sending script local affiliate bad abnormal local station report national event dont people scene address obviously becomes problem source local report dont let apostrophe terrorist win scale majority major news source handful corporation every year news medium becomes closer literal propaganda extremely dangerous democracy reply switch language tell people former soviet union propaganda bat eye switch language ill get expect project year give idea brand propaganda ’ angry look find propaganda propaganda friend reply extremely dangerous democracy extremely dangerous talking individual script real people extremely dangerous democracy government enjoy day state city citizen side side shouldnt power strong live consume watched year definitely iconic idea movie really really slow ending written year old make lot sense lot small news station actually one station network believe ’ video ’ ‘ show group yes right tough one arent name though create false sense competition get worse whole point make illegal anyone else broadcast think landing moon yet station exist station worth static government station whole reality carefully since kind give dont know anything news look like made different news network fox eyeball looking station fox eye thing youd think rule state broadcast propaganda yet shrug reply always like disillusionment morning go well coffee j ah man culture see raise j good sir may toke peace q would describe current state general sense role daily life concept miasma came neal ended pretty dark view kind tell book saw someone recently describe social medium current state doomsday machine think thats far weve turned perception whats real driven system designed human loop human loop theyre scalable theyre scalable cant make ton ton money result situation see today one factual reality everyone driven direction content engaging almost always mean emotional factually based rational kind destructive basic civics standpoint power understood early full nature power—its ability shatter semblance reality undermining civil society democratic governance process—was atlantic aesthetic great reality since universe hate u got stuck later none cool upgrade reply bot journalist extremely dangerous oh operation mockingbird folk look control narrative control people theyre medium talking point directed read air several time day come corporate right wing bias local news traditionally able steer clear political slant cable channel love think fox news v local fox channel local news bias local channel result local editorial freedom script mothership note different fox station theyre pushing right wing message respective local area traditionally would valued integrity edit e oh local news always kind garbage fluff local crime heavily propaganda machine though local editorial freedom gone individual editorial freedom individual may breaking away traditional method information still getting spoon fed whomever tune horse left barn plus year ago stopped anti trust law bribery call campaign donation almost every industry dominated handful company set agenda profit people lifetime 🤖 bot help video dont reply comment send link thats disturbing dont even live eventually come country every need see ...

# %%
reddit4.to_csv('result/csv1/reddit4.csv')

# %% [markdown]
# ### sffworld

# %%
sffworld=pd.read_json('result/json/sffworld.json')

# %%
sffworld.head()
# Out:
#       username       date                                              title  \
# 0  nposecznick 2016-01-15                Novels with Shadowrun-like setting?
# 1     SFFWorld 2021-10-12  New post - A SPINDLE SPLINTERED by Alix E. Har...
# 2         KatG 2021-01-28  Authors We've Lost -- Storm Constantine and An...
# 3     SFFWorld 2020-11-03  New post - THE ONCE AND FUTURE WITCHES by Alix...
# 4        Sfinx 2020-07-23                   Tips for summer holiday reading?
#
#    replies  views                                               text  Year
# 0        0     74  I was wondering if any of you could recommend ...  2016
# 1        6    248  Alix Harrow is a writer whose work has shown t...  2021
# 2        6    359  I meant to get something up on this earlier, b...  2021
# 3        3    274  Sisterhood. Women’s rights. Personhood. Witche...  2020
# 4       14    746  Hey all, Leaving soon for a couple of weeks of...  2020

# %%
sffworld["text"]=Preprocess_list_of_English_Sentence(sffworld["text"])

# %%
text = sffworld["text"].values 
matplotlib.rcParams['figure.figsize']=(10.0,5.0)

wordcloud = WordCloud().generate(str(text))

plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
vrow = sffworld.shape[0]
sffworld["sentiment"] = sffworld.text.apply(get_sentiment_en)

# %%
for i in range(vrow):
    text = sffworld["text"] .iloc[i]
    sffworld["sentiment"][i]=get_sentiment_en(text)
# Out:
# C:\Users\alplh\AppData\Local\Temp/ipykernel_4332/1512732929.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sffworld["sentiment"][i]=get_sentiment_en(text)

# %%
sffworld.head()
# Out:
#       username       date                                              title  \
# 0  nposecznick 2016-01-15                Novels with Shadowrun-like setting?
# 1     SFFWorld 2021-10-12  New post - A SPINDLE SPLINTERED by Alix E. Har...
# 2         KatG 2021-01-28  Authors We've Lost -- Storm Constantine and An...
# 3     SFFWorld 2020-11-03  New post - THE ONCE AND FUTURE WITCHES by Alix...
# 4        Sfinx 2020-07-23                   Tips for summer holiday reading?
#
#    replies  views                                               text  Year  \
# 0        0     74  wondering could recommend good book similar se...  2016
# 1        6    248  harrow writer whose work shown power story ’ r...  2021
# 2        6    359  meant get something let people fantasy author ...  2021
# 3        3    274  sisterhood woman ’ right witch harrow ’ second...  2020
# 4       14    746  hey leaving soon couple week sun sea plenty ti...  2020
#
#    sentiment
# 0   0.237500
# 1   0.050000
# 2   0.140000
# 3   0.087143
# 4  -0.250000

# %%
sffworld.to_csv('result/csv1/sffworld.csv')

# %% [markdown]
# ### usenet

# %%
usenet=pd.read_json('result/json/usenet.json')

# %%
usenet.head()
# Out:
#                                              content     date_post comment  \
# 0  News Flash!!  Back issues of the special Cyber...  572054400000      []
# 1  10. The Court's Final Judgement, Order, and De...  742521600000      []
# 2  Reprinted from The Globe and Mail, Thursday Ma...  576806400000      []
# 3  Awhile back I posted an article asking for spe...  564019200000      []
# 4  I hate to bother any of you out there with thi...  577065600000      []
#
#                                  idPost replyTo  \
# 0  bba8a573-1471-460a-8b73-f904d6219eaf       0
# 1  166b50d0-432c-43b2-a180-f5daf1b95d43       0
# 2  e44431c8-c337-4601-ba99-ecbc38dbb1c5       0
# 3  9cd86c17-11ad-40b9-aef5-4d11e1985adf       0
# 4  953a59b6-ac8f-47d5-aa00-80423bf4bd9c       0
#
#                                       idTopic  \
# 0              PDI2MDdAaGFkZG9jay5JU0MuQ09NPg
# 1  PDkzMDcxMzA2MjMuQUEwMTI4OEBwcmltdXMuY29tPg
# 2         PDM5ODRAd2F0Y2dsLndhdGVybG9vLmVkdT4
# 3              PDE3MDdAaGFkZG9jay5JU0MuQ09NPg
# 4                     PDM5NDU1Q09LQFBTVVZNQT4
#
#                                           titleTopic  Year
# 0                                Science Fiction EYE  1988
# 1  TLU&TN2 #10: The Court's Final Judgment, Order...  1993
# 2                       Cyberpunk approaches reality  1988
# 3                           Future Police -- thanks!  1987
# 4                                         This group  1988

# %%
usenet["content"]=Preprocess_list_of_English_Sentence(usenet["content"])

# %%
text = usenet["content"].values 
matplotlib.rcParams['figure.figsize']=(10.0,5.0)

wordcloud = WordCloud().generate(str(text))

plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
vrow = usenet.shape[0]
usenet["sentiment"] = usenet.content.apply(get_sentiment_en)

# %%
for i in range(vrow):
    text =  usenet["content"] .iloc[i]
    usenet["sentiment"][i]=get_sentiment_en(text)
# Out:
# C:\Users\alplh\AppData\Local\Temp/ipykernel_4332/325793037.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usenet["sentiment"][i]=get_sentiment_en(text)

# %%
usenet.head()
# Out:
#                                              content     date_post comment  \
# 0  news flash back issue special premiere science...  572054400000      []
# 1  court final order decree united state district...  742521600000      []
# 2  globe mail march without permission kiss chapp...  576806400000      []
# 3  awhile back posted article speculation like re...  564019200000      []
# 4  hate bother completely anybody many time trans...  577065600000      []
#
#                                  idPost replyTo  \
# 0  bba8a573-1471-460a-8b73-f904d6219eaf       0
# 1  166b50d0-432c-43b2-a180-f5daf1b95d43       0
# 2  e44431c8-c337-4601-ba99-ecbc38dbb1c5       0
# 3  9cd86c17-11ad-40b9-aef5-4d11e1985adf       0
# 4  953a59b6-ac8f-47d5-aa00-80423bf4bd9c       0
#
#                                       idTopic  \
# 0              PDI2MDdAaGFkZG9jay5JU0MuQ09NPg
# 1  PDkzMDcxMzA2MjMuQUEwMTI4OEBwcmltdXMuY29tPg
# 2         PDM5ODRAd2F0Y2dsLndhdGVybG9vLmVkdT4
# 3              PDE3MDdAaGFkZG9jay5JU0MuQ09NPg
# 4                     PDM5NDU1Q09LQFBTVVZNQT4
#
#                                           titleTopic  Year  sentiment
# 0                                Science Fiction EYE  1988   0.373347
# 1  TLU&TN2 #10: The Court's Final Judgment, Order...  1993   0.095362
# 2                       Cyberpunk approaches reality  1988   0.200000
# 3                           Future Police -- thanks!  1987   0.158824
# 4                                         This group  1988  -0.122917

# %%
usenet.to_csv('result/csv1/usenet.csv')

# %% [markdown]
# ## 法语处理

# %%
booknode=pd.read_json("result/json/booknode.json")

# %%
booknode.head()
# Out:
#                                    topicTitle  commentID       datePost  \
# 0  Quel couple préférez-vous dans Red Queen ?  p18443555  1473206400000
# 1  Quel couple préférez-vous dans Red Queen ?  p18443935  1473206400000
# 2  Quel couple préférez-vous dans Red Queen ?  p18444005  1473206400000
# 3  Quel couple préférez-vous dans Red Queen ?  p18446735  1473292800000
# 4  Quel couple préférez-vous dans Red Queen ?  p18447085  1473292800000
#
#                                              content links  \
# 0  Bonjour tout le monde !Si vous êtes comme moi ...    []
# 1  Tu n'es pas toute seule, je suis dans la team ...    []
# 2  Pour ma part, c'est également le couple Mare/M...    []
# 3  BLOCKQUOTEJe crois qu'on a tous eu la même réa...    []
# 4  Personnellement, j'ai horreur de Cal. Il est p...    []
#
#                                             img_link  \
# 0  [./images/smilies/icon_mrgreen.gif, ./images/s...
# 1  [./images/smilies/icon_e_biggrin.gif, ./images...
# 2  [./images/smilies/icon_e_biggrin.gif, ./images...
# 3  [./images/smilies/icon_e_sad.gif, ./images/smi...
# 4                                                 []
#
#                                           blockquote  nbPostTopic  \
# 0                                                 []           24
# 1                                                 []           24
# 2                                                 []           24
# 3  [LizzieB a écrit :Ce coup de théâtre m'a absol...           24
# 4                                                 []           24
#
#    nbViewsTopic  topicId  datePostTopic  lastUpdateTopic  Year
# 0            24   249255  1473206400000    1640995200000  2016
# 1            24   249255  1473206400000    1640995200000  2016
# 2            24   249255  1473206400000    1640995200000  2016
# 3            24   249255  1473206400000    1640995200000  2016
# 4            24   249255  1473206400000    1640995200000  2016

# %%
from french_lefff_lemmatizer.french_lefff_lemmatizer import FrenchLefffLemmatizer
def Preprocess_list_of_French_Sentence(listofSentence):
    # French Pre-processing
    french_stopwords = nltk.corpus.stopwords.words('french')
    Fwords = set(line.strip() for line in open('./dictionnaire.txt'))
    Frenchlemmatizer = FrenchLefffLemmatizer()
    
    preprocess_list = []
    for sentence in listofSentence :
        
        sentence_w_punct = "".join([i.lower() for i in sentence if i not in string.punctuation])
        
        sentence_w_num = ''.join(i for i in sentence_w_punct if not i.isdigit())
        
        tokenize_sentence = nltk.tokenize.word_tokenize(sentence_w_num)
        
        words_w_stopwords = [i for i in tokenize_sentence if i not in french_stopwords]
        
        words_lemmatize = (Frenchlemmatizer.lemmatize(w) for w in words_w_stopwords)
        
        sentence_clean = ' '.join(w for w in words_lemmatize if w.lower() in Fwords or not w.isalpha())
        # rebuild the text
        preprocess_list.append(sentence_clean)

    return preprocess_list

# %%
booknode["content"]=Preprocess_list_of_French_Sentence(booknode["content"])

# %%
text = booknode['content'].values 
matplotlib.rcParams['figure.figsize']=(10.0,5.0)

wordcloud = WordCloud().generate(str(text))

plt.imshow(wordcloud)
plt.axis("off")
plt.show()
